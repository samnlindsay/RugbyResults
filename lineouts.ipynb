# %%
from lineouts import *

# %%
l = Lineout(7, "A", receiver="9")

l.setup_chart()
# l.setup_chart().to_dict()
# l.throw_chart()
# l.play_chart()
# l.play_df()

# load_chart("json/play_7_A1_Flyby.json")

# save_charts(ns=7, receiver="F")
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Match Day Crib Sheet

# %%
opposition = "London Cornish (H)"

players = pd.DataFrame([
    {"Number": 1, "Name": "Guy", "Call": False, "Jump": False},
    {"Number": 2, "Name": "Totty", "Call": False, "Jump": False},
    {"Number": 3, "Name": "Brimo", "Call": False, "Jump": False},
    {"Number": 4, "Name": "Oli", "Call": True, "Jump": False},
    {"Number": 5, "Name": "SLM", "Call": False, "Jump": True},
    {"Number": 6, "Name": "Josh", "Call": False, "Jump": False},
    {"Number": 7, "Name": "Ryland", "Call": False, "Jump": True},
    {"Number": 8, "Name": "Dan", "Call": False, "Jump": True},
    {"Number": 9, "Name": "Chris", "Call": False, "Jump": False}
])

summary_chart(players, opposition, generic=False).to_dict()
# Out:
# {'config': {'view': {'continuousWidth': 300, 'continuousHeight': 300},
#   'style': {'cell': {'stroke': 'transparent'}}},
#  'layer': [{'layer': [{'mark': {'type': 'rule',
#       'color': 'whitesmoke',
#       'opacity': 0.5,
#       'strokeDash': [55, 55],
#       'strokeWidth': 6,
#       'y': 0,
#       'y2': 'height'},
#      'data': {'values': [{'x': 0}, {'x': 100}]},
#      'encoding': {'x': {'axis': None, 'field': 'x', 'type': 'quantitative'}}},
#     {'mark': {'type': 'rule',
#       'color': 'whitesmoke',
#       'opacity': 0.5,
#       'strokeWidth': 6},
#      'data': {'values': [{'xt': -50, 'y': 0}]},
#      'encoding': {'x': {'axis': None, 'field': 'xt', 'type': 'quantitative'}}},
#     {'mark': {'type': 'rule',
#       'color': '#22d',
#       'opacity': 1.0,
#       'strokeWidth': 1,
#       'x': -230,
#       'x2': 480},
#      'data': {'values': [{'yt': 17, 'x': 0},
#        {'yt': 62, 'x': 0},
#        {'yt': 87, 'x': 0}]},
#      'encoding': {'y': {'axis': None,
# ...

# %%
match_day_df(players)
# Out:
#            x   y Label Jumper  Order   A  Number    Name   Call   Jump   Color
# 0 -52.000000  95     2            -1  90       2   Totty  False  False    None
# 1   3.000000  95     L             1  90       3   Brimo  False  False    None
# 2  61.000000  95     J      2      2  90       5     SLM  False   True  Jumper
# 3  71.000000  95     J      1      3 -90       4     Oli   True  False  Caller
# 4  81.000000  95     L             4 -90       1     Guy  False  False    None
# 0 -52.000000  80     2            -1  90       2   Totty  False  False    None
# 1   3.000000  80     L             1  90       3   Brimo  False  False    None
# 2  33.000000  80     J      2      2   0       5     SLM  False   True  Jumper
# 3  43.000000  80     J      3      3   0       7  Ryland  False   True  Jumper
# 4  53.000000  80     J      1      4   0       4     Oli   True  False  Caller
# 5  83.000000  80     L             5 -90       1     Guy  False  False    None
# ...
